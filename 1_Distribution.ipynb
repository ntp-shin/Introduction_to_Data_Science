# %% [markdown]
# # **Phân bố dữ diệu - Distribution data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cbook
import seaborn as sns;sns.set()
# import numpy as np

# %% [markdown]
# ***Biểu diễn dữ liệu ở dạng Boxplot - từ đó quan sát và nhận xét sự phân bố dữ liệu***
# <img src = ".\image\Boxplot.png">

# %%
df = pd.read_csv('new_data.csv')
df.head()
# Out:
#    cum      sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0    1  1000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1    1  1000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2    1  1000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3    1  1000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4    1  1000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_ly  gdcd  phan_loai
# 0     6.0  8.75  THPT_KHXH
# 1     7.5  8.25  THPT_KHXH
# 2     5.5  8.75  THPT_KHXH
# 3     6.5  7.50  THPT_KHXH
# 4     8.5  8.25  THPT_KHXH

# %% [markdown]
# ### **1. Nhận xét về sự phân bố điểm theo từng môn**

# %%
column_name = ['toan', 'ngu_van', 'ngoai_ngu', 'vat_li',
               'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_ly', 'gdcd']

# %%
# Plot boxplot mon toan, ngu van
boxplot = df.boxplot(column=column_name, return_type='axes',
                     grid=False, vert=False, figsize=(20, 10), fontsize=15, color='red')
plt.title('Boxplot', fontsize=20)
plt.xlabel('Diem', fontsize=15)
plt.ylabel('Mon', fontsize=15)
plt.show()

# %% [markdown]
# **Tổng quan:** *Có sự phân bố điểm không đồng đều giữa các môn, sẽ chia làm 3 mức độ: dễ, trung bình, khó*
# - Khó - Ngoại ngữ _ Sinh học
#     - Đa số số thí sinh có điểm ở vùng trung bình - yếu
#     - 50% thí sinh đều dưới 5
# - Dễ - GDCD:
#     - Đa số thí sinh có điểm ở vùng khá - giỏi
#     - 50% thí sinh đều trên 8
#     - Đây có lẽ sẽ là lí do khiến mọi người đa số chọn KHXH để dễ tốt nghiệp hơn so với KHTN
# - Trung bình - Các môn còn lại:
#     - Đa số thí sinh có điểm ở vùng trung bình - khá
#     - 50% thí sinh từ 6.5 trở lên

# %% [markdown]
# #### *1.1 Môn toán*

# %%
toan = df['toan']
arr_value = [toan.quantile(0.25), toan.quantile(0.5), toan.quantile(0.75)]
boxplot = df.boxplot(column='toan', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - khá cụ thể là từ 5.4-7.8
# - Giá trị median là 6.8 cho thấy đề toán không quá khó mà cũng không quá dễ.

# %% [markdown]
# #### *1.2 Môn ngữ văn*

# %%
ngu_van = df['ngu_van']
arr_value = [ngu_van.quantile(0.25), ngu_van.quantile(0.5), ngu_van.quantile(0.75)]
boxplot = df.boxplot(column='ngu_van', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - khá cụ thể là từ 5.58-7.5
# - Giá trị median là 6.5 cho thấy đề ngữ văn không quá khó mà cũng không quá dễ.

# %% [markdown]
# #### *1.3 Môn ngoại ngữ*

# %%
ngoai_ngu = df['ngoai_ngu']
arr_value = [ngoai_ngu.quantile(0.25), ngoai_ngu.quantile(0.5), ngoai_ngu.quantile(0.75)]
boxplot = df.boxplot(column='ngoai_ngu', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - yếu cụ thể là từ 3.6 - 6.6
# - Giá trị median là 4.8 cho thấy đề ngoại ngữ rất khó.

# %% [markdown]
# #### *1.4 Môn vật lí && hóa học*

# %%
vat_li = df['vat_li']
hoa_hoc = df['hoa_hoc']
arr_value = [vat_li.quantile(0.25), vat_li.quantile(0.5), vat_li.quantile(0.75), hoa_hoc.quantile(0.25), hoa_hoc.quantile(0.5), hoa_hoc.quantile(0.75)]
boxplot = df.boxplot(column= ['vat_li', 'hoa_hoc'], return_type='axes',
                     grid=False, vert=False, figsize=(10, 4), fontsize=15, color='red')
for i in range(len(arr_value)):
    plt.text(arr_value[i] - 0.15, 0.25 + 0.2 * (i % 2), str(arr_value[i]), fontsize=10, color='blue')
    plt.axvline(arr_value[i], color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Hóa học và vật lí có phổ điểm khá tương đồng nhau, nằm ở mức trung bình - khá giỏi (5.5 - 7.75 8.0)
# - Đều có giá trị median là 7.0 - Cho thấy đề thi nằm ở mức vừa, tính chọn lọc cao.

# %% [markdown]
# #### *1.5 Môn sinh học*

# %%
sinh_hoc = df['sinh_hoc']
arr_value = [sinh_hoc.quantile(0.25), sinh_hoc.quantile(0.5), sinh_hoc.quantile(0.75)]
boxplot = df.boxplot(column='sinh_hoc', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - yếu cụ thể là từ 4.0-6.0
# - Giá trị median là 4.75 cho thấy đề sinh học rất khó.

# %% [markdown]
# #### *1.6 Môn địa lý && lịch sử*

# %%
dia_ly = df['dia_ly']
lich_su = df['lich_su']
arr_value = [dia_ly.quantile(0.25), dia_ly.quantile(0.5), dia_ly.quantile(0.75), lich_su.quantile(0.25), lich_su.quantile(0.5), lich_su.quantile(0.75)]
boxplot = df.boxplot(column= ['dia_ly', 'lich_su'], return_type='axes',
                     grid=False, vert=False, figsize=(10, 4), fontsize=15, color='red')
for i in range(len(arr_value)):
    plt.text(arr_value[i] - 0.15, 0.25 + 0.2 * (i % 2), str(arr_value[i]), fontsize=10, color='blue')
    plt.axvline(arr_value[i], color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Lịch sử và địa lý có phổ điểm khá tương đồng nhau, nằm ở mức trung bình - khá giỏi (5.25 - 7.5)
# - Đều có giá trị median khoảng 6.5 - Cho thấy đề thi nằm ở mức vừa, tính chọn lọc cao.

# %% [markdown]
# #### *1.7 Môn Giáo dục công dân*

# %%
gdcd = df['gdcd']
arr_value = [gdcd.quantile(0.25), gdcd.quantile(0.5), gdcd.quantile(0.75)]
boxplot = df.boxplot(column='gdcd', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng khá - giỏi cụ thể là từ 7.5-8.75
# - Giá trị median là 8.25 cho thấy đề giáo dục công dân rất dễ.

# %% [markdown]
# ### **2. Tính điểm trung bình tốt nghiệp DT1 & DT2 - kiểm tra đậu/rớt - tốt nghiệp loại gì?**

# %% [markdown]
# - Điểm tốt nghiệp của THPTQG DT1: $$ DXTN = \frac{Toan + NguVan + Ngoạingữ + average(KHTN/KHXH)}{6} $$
# - Điểm tốt nghiệp của GNTX DT2: $$ DXTN = \frac{Toan + NguVan + average(KHTN/KHXH)}{5} $$
# - *Đối với thí sinh thi lại đại học DT3 và thi sinh thi lại tốt nghiệp DT4 sẽ không tính điểm tốt nghiệp và không xếp loại tốt nghiệp vì không có đủ thông tin*

# %% [markdown]
# #### ***2.1 Tính điểm tốt nghiệp DT1 và DT2***

# %%
df['diem_tn'] = df.loc[(df['phan_loai'] != 'DH_RETEST') & (df['phan_loai'] != 'TH_RETEST'),
            ['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].mean(axis=1)

# %%
df[:500]
# Out:
#      cum      sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 0      1  1000001   3.6     5.00        4.0     NaN      NaN       NaN
# 1      1  1000002   8.4     6.75        7.6     NaN      NaN       NaN
# 2      1  1000003   5.8     7.50        5.0     NaN      NaN       NaN
# 3      1  1000004   7.4     7.50        8.6     NaN      NaN       NaN
# 4      1  1000005   7.2     8.50        9.0     NaN      NaN       NaN
# ..   ...      ...   ...      ...        ...     ...      ...       ...
# 495    1  1000508   NaN     7.25        NaN     NaN      NaN       NaN
# 496    1  1000509   NaN     7.25        NaN     NaN      NaN       NaN
# 497    1  1000510   NaN     3.50        NaN     NaN      NaN       NaN
# 498    1  1000511   NaN     5.50        NaN     NaN      NaN       NaN
# 499    1  1000512   NaN     1.50        NaN     NaN      NaN       NaN
#
#      lich_su  dia_ly  gdcd  phan_loai   diem_tn
# 0       2.75    6.00  8.75  THPT_KHXH  5.016667
# 1       8.50    7.50  8.25  THPT_KHXH  7.833333
# 2       7.25    5.50  8.75  THPT_KHXH  6.633333
# 3       7.50    6.50  7.50  THPT_KHXH  7.500000
# 4       8.00    8.50  8.25  THPT_KHXH  8.241667
# ..       ...     ...   ...        ...       ...
# 495     9.50    9.00   NaN  DH_RETEST       NaN
# 496     8.25    7.75   NaN  DH_RETEST       NaN
# 497     6.25    6.25   NaN  DH_RETEST       NaN
# 498     8.75    7.50   NaN  DH_RETEST       NaN
# 499     6.25    6.25   NaN  DH_RETEST       NaN
#
# [500 rows x 13 columns]

# %% [markdown]
# #### ***2.2 Xếp loại***

# %%
def classifier(row):
    if (pd.isna(row['diem_tn'])):
        return np.nan
    elif (min(row['toan'], row['ngu_van'], row['ngoai_ngu'], row['vat_li'], row['hoa_hoc'], row['sinh_hoc'], row['lich_su'], row['dia_ly'], row['gdcd']) < 1):
        return 'Rot'
    elif (row['diem_tn'] >= 8):
        return 'Gioi'
    elif (row['diem_tn'] >= 6.5):
        return 'Kha'
    elif (row['diem_tn'] >= 4.5):
        return 'Trung binh'
    else: return 'Rot'

df['xep_loai_tn'] = df.apply(classifier, axis = 1)

# %%
df.head()
# Out:
#    cum      sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0    1  1000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1    1  1000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2    1  1000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3    1  1000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4    1  1000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_ly  gdcd  phan_loai   diem_tn xep_loai_tn
# 0     6.0  8.75  THPT_KHXH  5.016667  Trung binh
# 1     7.5  8.25  THPT_KHXH  7.833333         Kha
# 2     5.5  8.75  THPT_KHXH  6.633333         Kha
# 3     6.5  7.50  THPT_KHXH  7.500000         Kha
# 4     8.5  8.25  THPT_KHXH  8.241667        Gioi

# %% [markdown]
# #### ***2.3 Phân loại đối tượng theo từng Data Frame***

# %%
df_dt1 = df.loc[(df['phan_loai'] == 'THPT_KHXH') | (df['phan_loai'] == 'THPT_KHTN')]
df_dt2 = df.loc[(df['phan_loai'] == 'GDTX_KHXH') | (df['phan_loai'] == 'GDTX_KHTN')]
df_dt3 = df.loc[(df['phan_loai'] == 'DH_RETEST')]
df_dt4 = df.loc[(df['phan_loai'] == 'TH_RETEST')]

# %% [markdown]
# #### ***2.4 Đối tượng 1 - Tham gia thi THPTQG***

# %%
fig = plt.figure(figsize=(3,3))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
students = df_dt1.groupby(['xep_loai_tn'])['xep_loai_tn'].count()
ax.pie(students,labels = students.keys(), autopct = '%1.2f%%')
plt.title('Tỉ lệ xếp loại THPTQG', fontsize=15, fontweight='bold', color='blue')
plt.show()

# %% [markdown]
# **Đánh giá**
# - Có 96.57% thí sinh đậu tốt nghiệp, cho thấy tỉ lệ tốt nghiệp ở THPTQG là rất cao
# - Tuy nhiên đa số xếp loại rơi vào Khá và Trung bình và chỉ có 5.6% xếp loại giỏi
# - Cho thấy kì thi này thí sinh lấy điểm xét đại học là chính, chỉ cần đủ tốt nghiệp là được

# %% [markdown]
# #### ***2.5 Đối tượng 2 - Tham gia theo GDTX***

# %%
fig = plt.figure(figsize=(3,3))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
students = df_dt2.groupby(['xep_loai_tn'])['xep_loai_tn'].count()
ax.pie(students,labels = students.keys(), autopct = '%1.2f%%')
plt.title('Tỉ lệ xếp loại GDTX', fontsize=15, fontweight='bold', color='blue')
plt.show()

# %% [markdown]
# ***Đánh giá***
# - Chỉ có 3.42% rớt và có đến 96.58% đậu tốt nghiệp
# - Tỉ lệ đậu tốt nghiệp giữa THPTQG và GDTX gần như nhau
# - *Môn ngoại ngữ không ảnh hưởng nhiều đến tỉ lệ tốt nghiệp*

# %% [markdown]
# ### **3. So sánh các đối tượng**

# %% [markdown]
# - Nhận xét về số lượng, tỉ lệ rồi đánh giá
# - Đánh giá tỉ lệ tốt nghiệp, so sánh giữa dt1 và dt2
# - Phân bố điểm trung bình của dt1 và dt2
# - Loại tốt nghiệp theo từng đối từng

# %% [markdown]
# #### ***3.1 Số lượng thí sinh của 4 đối tượng***

# %%
students = np.array([len(df_dt1),len(df_dt2),len(df_dt3),len(df_dt4)])
fig, ax = plt.subplots()
ind = np.arange(4)
width = 0.3

ax.bar(ind - width/2,students, width)
ax.set_ylabel('Number of Students')
ax.set_title('Distribution of students')
ax.set_xticks(ind)
ax.set_xticklabels(('THPTQG','GDTX','DH_RETEST','TH_RETEST'),fontsize=8)
[plt.text(ind[i] - width/2, students[i] + 0.1, str(students[i]), fontsize=10, color='blue') for i in range(len(students))]

plt.show()

# %% [markdown]
# **Nhận xét**
# - Đa số thí sinh là học sinh THPT đăng kí thi THPTQG với số lượng 858,736 (hơn 850 ngàn) thí sinh
# - Đứng thứ 2 là số thí sinh thi lại đại học chứ không phải GDTX như mọi người thường nghĩ - với số lượng 125,000 người
# - GDTX chỉ có gần 10,000 thí sinh chưa bằng 1/10 so với DH_RETEST
# - Cuối cùng là thi lại tốt nghiệp, chỉ vỏn vẹn 1000 người. **=> Không đánh giá hay nhận xét DT4**

# %% [markdown]
# #### ***3.2 Tổng điểm 3 môn cao nhất***

# %%
df_dt2.head()
# Out:
#     cum      sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  \
# 11    1  1000012   6.4     7.50        NaN     NaN      NaN       NaN
# 18    1  1000019   6.8     7.50        NaN     NaN      NaN       NaN
# 20    1  1000021   8.0     9.00        NaN     NaN      NaN       NaN
# 49    1  1000050   7.4     7.25        NaN     NaN      NaN       NaN
# 73    1  1000074   7.6     6.50        NaN     7.5      2.5      1.75
#
#     lich_su  dia_ly  gdcd  phan_loai  diem_tn xep_loai_tn
# 11     4.75    5.00  8.00  GDTX_KHXH     6.33  Trung binh
# 18     7.25    6.25  8.00  GDTX_KHXH     7.16         Kha
# 20     7.00    6.25  8.75  GDTX_KHXH     7.80         Kha
# 49     4.75    6.00  7.25  GDTX_KHXH     6.53         Kha
# 73      NaN     NaN   NaN  GDTX_KHTN     5.17  Trung binh

# %%
def sumhighest3subjects(row):
    arr = []
    for score in ['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']:
        if(~np.isnan(row[score])):
            arr.append(row[score])
    arr.sort(reverse=True)
    return sum(arr[:3])

df_dt1['score3Sub'] = df_dt1.apply(sumhighest3subjects, axis = 1)
df_dt2['score3Sub'] = df_dt2.apply(sumhighest3subjects, axis = 1)
df_dt3['score3Sub'] = df_dt3.apply(sumhighest3subjects, axis = 1)
# Out:
# C:\Users\tphat\AppData\Local\Temp\ipykernel_35136\777565817.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt1['score3Sub'] = df_dt1.apply(sumhighest3subjects, axis = 1)
# C:\Users\tphat\AppData\Local\Temp\ipykernel_35136\777565817.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt2['score3Sub'] = df_dt2.apply(sumhighest3subjects, axis = 1)
# C:\Users\tphat\AppData\Local\Temp\ipykernel_35136\777565817.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dt3['score3Sub'] = df_dt3.apply(sumhighest3subjects, axis = 1)

# %%
def boxplot(data, namevalue, title):
    dt3 = data[namevalue]
    arr_value = [round(dt3.quantile(0.25), 2), round(dt3.quantile(0.5), 2), round(dt3.quantile(0.75), 2), round(dt3.quantile(1.00), 2)]
    boxplot = data.boxplot(column=namevalue, return_type='axes',
                        grid=False, vert=False, figsize=(8, 0.5), fontsize=15, color='red')
    for i in arr_value:
        plt.text(i - 0.15, 0.5, str(i), fontsize=10, color='blue')
        plt.axvline(i, color='black', linestyle='--', linewidth=1)
    plt.title(title, fontsize=15, fontweight='bold', color='blue')
    plt.axvline(30, color='black', linestyle='--', linewidth=1)
    plt.show()

# %%
boxplot(df_dt1, 'score3Sub', 'THPTQG')
boxplot(df_dt2, 'score3Sub', 'GDTX')
boxplot(df_dt3, 'score3Sub', 'DH_RETEST')

# %% [markdown]
# **THPTQG và GDTX**
# - Đều đạt điểm trong vùng 20.5 - 24.5
# - Vượt mức điểm sàn của toàn bộ trường đại học.
# - Với 22 - 24 điểm => Có thể đậu rất nhiều trường / ngành nghề
# - ***Tuy nhiên, hiện nay rất nhiều trường đã bổ sung thêm hình thức xét tuyển (Đánh giá năng lực, tuyển thẳng, kì thi riêng,...) do đó hình thức THPTQG phải giảm chỉ tiêu xuống => Dẫn đến các ngành / nghề hot có điểm chuẩn rất cao (27 - 29.5).***
#
# **Đại học - Thi lại**
# - Đa số điểm nằm ở vùng từ 15.55 - 21.3
# - Với số điểm này thì thí sinh vượt qua điểm sàn của đa số tất cả các trường đại học
# - Giá trị median là 18.4 => Khả năng cao đậu các ngành nghề tầm trung (ít cạnh tranh)
# - Giá trị max của DT3 là 29.35 => Thấp hơn DT1 => Dễ hiểu, vì đây là điểm của thí sinh thi lại, những người đạt điểm cao của năm trước chắc chắn đã đậu đại học rồi.
# - ***Tuy nhiên, dù là thi lại nhưng giá trị median lại thấp hơn so với DT1 và DT2 => Vì tổ hợp Sử_Địa_GDCD quá dễ? hay vì chủ quan => Cùng xem xét ở phần dự đoán khối thi.***

# %% [markdown]
# #### **3.3 So sánh median từng môn của DT1 và DT3**

# %%
df_compare_median = pd.Series()
df_compare_median['THPTQG'] = pd.array(df_dt1[['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].quantile(0.5))
df_compare_median['DH_RETEST'] = pd.array(df_dt3[['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].quantile(0.5))
# Out:
# C:\Users\tphat\AppData\Local\Temp\ipykernel_35136\2502289960.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df_compare_median = pd.Series()

# %%
fig, ax = plt.subplots(figsize=(15,5) )
ind = np.arange(9)
width = 0.3
fig = (29,5)
r1 = ax.bar(ind - width/2, df_compare_median['THPTQG'], width, label = 'THPTQG')
r2 = ax.bar(ind + width/2, df_compare_median['DH_RETEST'], width, label ='DH_RETEST')

ax.set_ylabel('Scores')
ax.set_title('Median scores', fontsize=15, fontweight='bold', color='blue')
[plt.text(ind[i] - width/2, df_compare_median['THPTQG'][i] + 0.1, str(df_compare_median['THPTQG'][i]), 
                fontsize=10, color='blue') for i in range(len(df_compare_median['THPTQG']))]
[plt.text(ind[i] + width/2, df_compare_median['DH_RETEST'][i] + 0.1, str(df_compare_median['DH_RETEST'][i]), 
                fontsize=10, color='red') for i in range(len(df_compare_median['DH_RETEST']))]
ax.set_xticks(ind)
ax.set_xticklabels(('toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd'),fontsize=8)
ax.legend()

plt.show()

# %% [markdown]
# **Nhận xét**
# - Đối với Toán và Ngữ văn: đa số học sinh thi THPTQG đều cao hơn Thi_lại_DH 1 - 2 điểm. => Hai môn này không được các thí sinh DT3 coi trọng. Hoặc là do sự ảnh hưởng của các thi sinh thi khối không có môn Toán (Văn)
# - Đối với Ngoại ngữ và Sinh học: thì ngược lại so với trên, Thi_lại_DH cao hơn hẳn so với THPTQG => Một phần vì đây là 2 môn khó nhất trong tất cả các môn và cũng một phần đây là các được DT3 chú trọng.
# - Đối với Vật lý và Hóa học: điểm DT3 có nhỉnh hơn một chút so với DT1 => Kết hợp với điều trên => Đa số DT3 thi khối A (Toán Lý Hóa) khối A1(Toán Lý Anh) khối B (Toán Hóa Sinh)
# - Các môn còn lại Sử_Địa_GDCD: DT1 nhỉnh hơn DT3 => Vì khối khoa học xã hội dễ, được nhiều DT1 chọn để tốt thi tốt nghiệp. Còn DT3 đã đậu tốt nghiệp rồi nên không cần để ý nhiều.
