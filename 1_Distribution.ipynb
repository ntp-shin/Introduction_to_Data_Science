# %% [markdown]
# # **Phân bố dữ diệu - Distribution data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cbook
import seaborn as sns;sns.set()
# import numpy as np

# %% [markdown]
# ***Biểu diễn dữ liệu ở dạng Boxplot - từ đó quan sát và nhận xét sự phân bố dữ liệu***
# <img src = ".\image\Boxplot.png">

# %%
df = pd.read_csv('new_data.csv')
df.head()
# Out:
#    cum      sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0    1  1000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1    1  1000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2    1  1000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3    1  1000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4    1  1000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_ly  gdcd  phan_loai
# 0     6.0  8.75  THPT_KHXH
# 1     7.5  8.25  THPT_KHXH
# 2     5.5  8.75  THPT_KHXH
# 3     6.5  7.50  THPT_KHXH
# 4     8.5  8.25  THPT_KHXH

# %% [markdown]
# ### **1. Nhận xét về sự phân bố điểm theo từng môn**

# %%
column_name = ['toan', 'ngu_van', 'ngoai_ngu', 'vat_li',
               'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_ly', 'gdcd']

# %%
# Plot boxplot mon toan, ngu van
boxplot = df.boxplot(column=column_name, return_type='axes',
                     grid=False, vert=False, figsize=(20, 10), fontsize=15, color='red')
plt.title('Boxplot', fontsize=20)
plt.xlabel('Diem', fontsize=15)
plt.ylabel('Mon', fontsize=15)
plt.show()

# %% [markdown]
# **Tổng quan:** *Có sự phân bố điểm không đồng đều giữa các môn, sẽ chia làm 3 mức độ: dễ, trung bình, khó*
# - Khó - Ngoại ngữ _ Sinh học
#     - Đa số số thí sinh có điểm ở vùng trung bình - yếu
#     - 50% thí sinh đều dưới 5
# - Dễ - GDCD:
#     - Đa số thí sinh có điểm ở vùng khá - giỏi
#     - 50% thí sinh đều trên 8
#     - Đây có lẽ sẽ là lí do khiến mọi người đa số chọn KHXH để dễ tốt nghiệp hơn so với KHTN
# - Trung bình - Các môn còn lại:
#     - Đa số thí sinh có điểm ở vùng trung bình - khá
#     - 50% thí sinh từ 6.5 trở lên

# %% [markdown]
# #### *1.1 Môn toán*

# %%
toan = df['toan']
arr_value = [toan.quantile(0.25), toan.quantile(0.5), toan.quantile(0.75)]
boxplot = df.boxplot(column='toan', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - khá cụ thể là từ 5.4-7.8
# - Giá trị median là 6.8 cho thấy đề toán không quá khó mà cũng không quá dễ.

# %% [markdown]
# #### *1.2 Môn ngữ văn*

# %%
ngu_van = df['ngu_van']
arr_value = [ngu_van.quantile(0.25), ngu_van.quantile(0.5), ngu_van.quantile(0.75)]
boxplot = df.boxplot(column='ngu_van', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - khá cụ thể là từ 5.58-7.5
# - Giá trị median là 6.5 cho thấy đề ngữ văn không quá khó mà cũng không quá dễ.

# %% [markdown]
# #### *1.3 Môn ngoại ngữ*

# %%
ngoai_ngu = df['ngoai_ngu']
arr_value = [ngoai_ngu.quantile(0.25), ngoai_ngu.quantile(0.5), ngoai_ngu.quantile(0.75)]
boxplot = df.boxplot(column='ngoai_ngu', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - yếu cụ thể là từ 3.6 - 6.6
# - Giá trị median là 4.8 cho thấy đề ngoại ngữ rất khó.

# %% [markdown]
# #### *1.4 Môn vật lí && hóa học*

# %%
vat_li = df['vat_li']
hoa_hoc = df['hoa_hoc']
arr_value = [vat_li.quantile(0.25), vat_li.quantile(0.5), vat_li.quantile(0.75), hoa_hoc.quantile(0.25), hoa_hoc.quantile(0.5), hoa_hoc.quantile(0.75)]
boxplot = df.boxplot(column= ['vat_li', 'hoa_hoc'], return_type='axes',
                     grid=False, vert=False, figsize=(10, 4), fontsize=15, color='red')
for i in range(len(arr_value)):
    plt.text(arr_value[i] - 0.15, 0.25 + 0.2 * (i % 2), str(arr_value[i]), fontsize=10, color='blue')
    plt.axvline(arr_value[i], color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Hóa học và vật lí có phổ điểm khá tương đồng nhau, nằm ở mức trung bình - khá giỏi (5.5 - 7.75 8.0)
# - Đều có giá trị median là 7.0 - Cho thấy đề thi nằm ở mức vừa, tính chọn lọc cao.

# %% [markdown]
# #### *1.5 Môn sinh học*

# %%
sinh_hoc = df['sinh_hoc']
arr_value = [sinh_hoc.quantile(0.25), sinh_hoc.quantile(0.5), sinh_hoc.quantile(0.75)]
boxplot = df.boxplot(column='sinh_hoc', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - yếu cụ thể là từ 4.0-6.0
# - Giá trị median là 4.75 cho thấy đề sinh học rất khó.

# %% [markdown]
# #### *1.6 Môn địa lý && lịch sử*

# %%
dia_ly = df['dia_ly']
lich_su = df['lich_su']
arr_value = [dia_ly.quantile(0.25), dia_ly.quantile(0.5), dia_ly.quantile(0.75), lich_su.quantile(0.25), lich_su.quantile(0.5), lich_su.quantile(0.75)]
boxplot = df.boxplot(column= ['dia_ly', 'lich_su'], return_type='axes',
                     grid=False, vert=False, figsize=(10, 4), fontsize=15, color='red')
for i in range(len(arr_value)):
    plt.text(arr_value[i] - 0.15, 0.25 + 0.2 * (i % 2), str(arr_value[i]), fontsize=10, color='blue')
    plt.axvline(arr_value[i], color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Lịch sử và địa lý có phổ điểm khá tương đồng nhau, nằm ở mức trung bình - khá giỏi (5.25 - 7.5)
# - Đều có giá trị median khoảng 6.5 - Cho thấy đề thi nằm ở mức vừa, tính chọn lọc cao.

# %% [markdown]
# #### *1.7 Môn Giáo dục công dân*

# %%
gdcd = df['gdcd']
arr_value = [gdcd.quantile(0.25), gdcd.quantile(0.5), gdcd.quantile(0.75)]
boxplot = df.boxplot(column='gdcd', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng khá - giỏi cụ thể là từ 7.5-8.75
# - Giá trị median là 8.25 cho thấy đề giáo dục công dân rất dễ.

# %% [markdown]
# ### **2. Tính điểm trung bình tốt nghiệp - kiểm tra đậu/rớt - tốt nghiệp loại gì?**

# %% [markdown]
# - **Điểm tốt nghiệp của THPTQG DT1:** $$ DXTN = \frac{Toán + Ngữvăn + Ngoạingữ + 3mônKHTN/KHXH}{6} $$
# - **Điểm tốt nghiệp của GNTX DT2:** $$ DXTN = \frac{Toán + Ngữvăn + 3mônKHTN/KHXH}{5} $$
# - **Đối với thí sinh thi lại đại học DT3 và thi sinh thi lại tốt nghiệp DT4 sẽ không có điểm tốt nghiệp và không xếp loại tốt nghiệp**

# %%
df['diem_tn'] = df.loc[(df['phan_loai'] != 'DH_RETEST') & (df['phan_loai'] != 'TH_RETEST'),['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].mean(axis=1)

def classifier(row):
    if ((row['toan'] < 1) | (row['ngu_van'] < 1) | (row['ngoai_ngu'] < 1) | (row['vat_li'] < 1) | (row['hoa_hoc'] < 1) | (row['sinh_hoc'] < 1) | (row['lich_su'] < 1) | (row['dia_ly'] < 1) | (row['gdcd'] < 1)):
        return 'Rot'
    elif (row['diem_tn'] >= 8):
        return 'Gioi'
    elif (row['diem_tn'] >= 6.5):
        return 'Kha'
    elif (row['diem_tn'] >= 5):
        return 'Trung binh'
    elif (pd.isna(row['diem_tn'])):
        return np.nan
    else: return 'Rot'

df['xep_loai_tn'] = df.apply(classifier, axis = 1)

# %%
df.head()
# Out:
#    cum      sbd  toan  ngu_van  ngoai_ngu  vat_li  hoa_hoc  sinh_hoc  lich_su  \
# 0    1  1000001   3.6     5.00        4.0     NaN      NaN       NaN     2.75
# 1    1  1000002   8.4     6.75        7.6     NaN      NaN       NaN     8.50
# 2    1  1000003   5.8     7.50        5.0     NaN      NaN       NaN     7.25
# 3    1  1000004   7.4     7.50        8.6     NaN      NaN       NaN     7.50
# 4    1  1000005   7.2     8.50        9.0     NaN      NaN       NaN     8.00
#
#    dia_ly  gdcd  phan_loai   diem_tn xep_loai_tn
# 0     6.0  8.75  THPT_KHXH  5.016667  Trung binh
# 1     7.5  8.25  THPT_KHXH  7.833333         Kha
# 2     5.5  8.75  THPT_KHXH  6.633333         Kha
# 3     6.5  7.50  THPT_KHXH  7.500000         Kha
# 4     8.5  8.25  THPT_KHXH  8.241667        Gioi

# %% [markdown]
# ### **3. Phân bố theo các đối tượng**

# %% [markdown]
# - Nhận xét về số lượng, tỉ lệ rồi đánh giá
# - Đánh giá tỉ lệ tốt nghiệp, so sánh giữa dt1 và dt2
# - Phân bố điểm trung bình của dt1 và dt2
# - Loại tốt nghiệp theo từng đối từng

# %%
df_dt1 = df.loc[(df['phan_loai'] == 'THPT_KHXH') | (df['phan_loai'] == 'THPT_KHTN')]
df_dt2 = df.loc[(df['phan_loai'] == 'GDTX_KHXH') | (df['phan_loai'] == 'GDTX_KHTN')]
df_dt3 = df.loc[(df['phan_loai'] == 'DH_RETEST')]
df_dt4 = df.loc[(df['phan_loai'] == 'TH_RETEST')]

# %% [markdown]
# #####   Biểu đồ số lượng các lớp dữ liệu

# %%
students = np.array([len(df_dt1),len(df_dt2),len(df_dt3),len(df_dt4)])
fig, ax = plt.subplots()
ind = np.arange(4)
width = 0.3

ax.bar(ind - width/2, students, width)
ax.set_ylabel('Students')
ax.set_title('Distribution of students')
ax.set_xticks(ind)
ax.set_xticklabels(('THPTQG','GDTX','DH_RETEST','TH_RETEST'),fontsize=8)


plt.show()

# %% [markdown]
# ##### Biểu đồ tỉ lệ các lớp dữ liệu

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
lengs = ['THPTQG','GDTX','DH_RETEST','TH_RETEST']
students = [len(df_dt1),len(df_dt2),len(df_dt3),len(df_dt4)]
ax.pie(students,labels = lengs, autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# ##### Nhận xét
# - Đựa vào biểu đồ ta thấy có 86.27% thí xin thi với hình thức THPTQG, 12.64% là thí sinh thi lại đại học, còn lại là thí sinh từ trung tâm GDTX và thi lại tốt nghiệp

# %% [markdown]
# #### *3.1 Tham gia thi THPT QG DT1*

# %% [markdown]
# ##### Biểu đồ xếp loại tốt nghiệp các thí sinh thi THPTQG

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
students = df_dt1.groupby(['xep_loai_tn'])['xep_loai_tn'].count()
ax.pie(students,labels = students.keys(), autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# ##### Nhận xét
# - Có 858736 thi sinh thi THPTQG
# - 5.6% thí sinh tốt nghiệp loại giỏi
# - 44.01% thí sinh tốt nghiệp loại khá
# - 41.85% thí sinh tốt nghiệp loại trung bình
# - 8.54% thí sinh rớt tốt nghiệp
# ##### Đánh giá
# - Có 91.46% thí sinh đậu tốt nghiệp, cho thấy tỉ lệ tốt nghiệp ở THPTQG là rất cao

# %% [markdown]
# ##### Biểu đồ boxplot GDTX

# %%
THPTQG = df_dt1['diem_tn']
arr_value = [THPTQG.quantile(0.25), THPTQG.quantile(0.5), THPTQG.quantile(0.75)]
boxplot = df_dt1.boxplot(column='diem_tn', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(round(i,2)), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - khá cụ thể là từ 5.77-7.17
# - Giá trị median là 6.48 cho thấy tổng thế đề thi năm nay đối với thí sinh THPTQG không quá khó cũng không quá dễ.

# %% [markdown]
# #### *3.2 Giáo dục thường xuyên DT2*

# %% [markdown]
# ##### Biểu đồ xếp loại tốt nghiệp các thí sinh thuộc trung tâm GDTX

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
students = df_dt2.groupby(['xep_loai_tn'])['xep_loai_tn'].count()
ax.pie(students,labels = students.keys(), autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# ##### Nhận xét
# - Có 9821 thí sinh của Trung tâm GDTX
# - 9.99% thí sinh tốt nghiệp loại giỏi
# - 49.64% thí sinh tốt nghiệp loại khá
# - 32.5% thí sinh tốt nghiệp loại trung bình
# - 7.87% thí sinh rớt tốt nghiệp
# ##### Đánh giá
# - Có 92.13% thí sinh đậu tốt nghiệp, cho thấy tỉ lệ tốt nghiệp ở Trung tâm GDTX là rất cao
# - Tỉ lệ đậu tốt nghiệp giữa THPTQG và GDTX gần như nhau

# %% [markdown]
# ##### Biểu đồ boxplot GDTX

# %%
GDTX = df_dt2['diem_tn']
arr_value = [GDTX.quantile(0.25), GDTX.quantile(0.5), GDTX.quantile(0.75)]
boxplot = df_dt2.boxplot(column='diem_tn', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng trung bình - khá cụ thể là từ 5.96-7.5
# - Giá trị median là 6.8 cho thấy tổng thế đề thi năm nay đối với thí sinh của GDTX không quá khó cũng không quá dễ.
# - Ta thấy vùng phân bố và điểm median của THPTQG và TDGT gần như nhau

# %% [markdown]
# #### *3.3 Thi lại đại học DT3 (Đã tốt nghiệp THPT)*

# %% [markdown]
# ##### Tổng điểm thi 3 môn cao nhất

# %%
def sumhighest3subjects(row):
    temp = pd.Series([row['toan'],row['ngu_van'],row['ngoai_ngu'],row['vat_li'],row['hoa_hoc'],row['sinh_hoc'],row['lich_su'],row['dia_ly'],row['gdcd']])
    temp = temp.sort_values(ascending=False)
    sum = 0
    for i in temp[:3]:
        sum += i
    return sum
    

df_dt3['tong_diem_3_mon'] = df_dt3.apply(sumhighest3subjects, axis = 1)

# %%
DH_RETEST = df_dt3['tong_diem_3_mon']
arr_value = [DH_RETEST.quantile(0.25), DH_RETEST.quantile(0.5), DH_RETEST.quantile(0.75)]
boxplot = df_dt3.boxplot(column='tong_diem_3_mon', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng từ 15.55-21.3
# - Giá trị median là 18.4 cho thấy tổng thế điểm 3 môn cao nhất của các thí sinh thi lại đại học là tương đối với các trường đại học chất lượng top

# %% [markdown]
# ##### So sánh và đánh giá chỉ số mean và median từng môn của THPTQG và DH_RETEST

# %%
df_compare_mean = pd.Series()
df_compare_mean['THPTQG'] = pd.array(df_dt1[['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].mean(axis = 0))
df_compare_mean['DH_RETEST'] = pd.array(df_dt3[['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].mean(axis = 0))
df_compare_median = pd.Series()
df_compare_median['THPTQG'] = pd.array(df_dt1[['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].quantile(0.5))
df_compare_median['DH_RETEST'] = pd.array(df_dt3[['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].quantile(0.5))

# %% [markdown]
# ##### Biểu đồ so sánh chỉ số mean từng môn của THPTQG với DH_RETEST

# %%
fig, ax = plt.subplots()
ind = np.arange(9)
width = 0.3
fig = (29,5)
r1 = ax.bar(ind - width/2, df_compare_mean['THPTQG'], width, label = 'THPTQG')
r2 = ax.bar(ind + width/2, df_compare_mean['DH_RETEST'], width, label ='DH_RETEST')

ax.set_ylabel('Scores')
ax.set_title('Mean scores')
ax.set_xticks(ind)
ax.set_xticklabels(('toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd'),fontsize=8)
ax.legend()

plt.show()

# %% [markdown]
# ##### Biểu đồ so sánh chỉ số median từng môn của THPTQG với DH_RETEST

# %%
fig, ax = plt.subplots()
ind = np.arange(9)
width = 0.3
fig = (29,5)
r1 = ax.bar(ind - width/2, df_compare_median['THPTQG'], width, label = 'THPTQG')
r2 = ax.bar(ind + width/2, df_compare_median['DH_RETEST'], width, label ='DH_RETEST')

ax.set_ylabel('Scores')
ax.set_title('Median scores')
ax.set_xticks(ind)
ax.set_xticklabels(('toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd'),fontsize=8)
ax.legend()

plt.show()

# %% [markdown]
# ##### Đánh giá
# - Điểm trung bình các môn của thí sinh thi lại đại học gần với các thí sinh thi THPTQG
# - Trung bình và median môn toán thấp hơn 1.5 , 2 điểm so với các thi sinh THPTQG, 1 phần do đề khó hơn năm trước, 1 phần do kiến thức của thí sinh thi lại bỏ bị thiếu sót cũng như không năm chắc bằng THPTQG khi vừa chuẩn bị thi.
# - Trung bình và median môn ngữ văn thấp hơn 1 đến 2 điểm số với các thí sinh THPTQG, do đề văn mỗi năm đổi mới, đánh đố thí sinh và cũng như lý do như toán là kiến thức không gần như không sát bằng THPTQG
# - Các môn như lịch sử, địa lý, gdcd thấp hơn nhưng không nhiều có thể do 1 số câu bẫy mới thêm vào khiến chênh lệch là không nhiều
# - Trung bình và median môn ngoại ngữ là môn đột phá, cao hơn 1.5, 2 điểm số với THPTQG do đây là môn cần thiết trong xã hội nên thường được chú trọng, 1 phần để tốt nghiệp, 1 phần xin việc
# - Các môn như vật lí, hoá học, sinh học cao hơn THPTQG nhưng rất ít

# %% [markdown]
# #### *3.4 Thi lại tốt nghiệp DT4 (Chưa tốt nghiệp THPT*)

# %%
df_dt4['diem_tb'] = df_dt4.loc[:,['toan','ngu_van', 'ngoai_ngu','vat_li','hoa_hoc','sinh_hoc','lich_su', 'dia_ly', 'gdcd']].mean(axis=1)

# %% [markdown]
# ##### Biểu đồ xếp loại tốt nghiệp các thí sinh thi lại THPTQG

# %%
TH_RETEST = df_dt4['diem_tb']
arr_value = [TH_RETEST.quantile(0.25), TH_RETEST.quantile(0.5), TH_RETEST.quantile(0.75)]
boxplot = df_dt4.boxplot(column='diem_tb', return_type='axes',
                     grid=False, vert=False, figsize=(10, 2), fontsize=15, color='red')
for i in arr_value:
    plt.text(i - 0.15, 0.3, str(i), fontsize=10, color='blue')
    plt.axvline(i, color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# - Đa số điểm nằm ở vùng từ 4.5-7.5
# - Giá trị median là 6.25 cho thấy tổng thể các thi sinh thi lại tốt nghiệp đều đủ điểm tốt nghiệp
